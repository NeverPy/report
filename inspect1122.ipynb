# %%
import os,time
date=(time.strftime("%Y%m%d"))
localfile_init=input("请输入巡检报告本地存储路径：")
localfile = r'D:\GitHub\report' + '\\' + date + '.xyh.txt'
localfile_new = localfile_init + '\\' + date + '.xyh.txt'
print(localfile,localfile_new)
import msvcrt
msvcrt.getch()
# Out:
# 请输入巡检报告本地存储路径：d:\new
# D:\GitHub\report\20181122.xyh.txt d:\new\20181122.xyh.txt

# %%
import paramiko
import os,time
import chardet
import sys 
import msvcrt
def mkdir(path):
    # 引入模块
    import os
 
    # 去除首位空格
    path=path.strip()
    # 去除尾部 \ 符号
    path=path.rstrip("\\")
 
    # 判断路径是否存在
    # 存在     True
    # 不存在   False
    isExists=os.path.exists(path)
 
    # 判断结果
    if not isExists:
        # 如果不存在则创建目录
        # 创建目录操作函数
        os.makedirs(path) 
 
        print (path+' 创建成功')
        return True
    else:
        # 如果目录存在则不创建，并提示目录已存在
        print (path+' 目录已存在')
        return False

# 将10.15.1.27的巡检报告传送到本地D:\GitHub\report
localfile_init=input("请输入巡检报告本地存储路径：")
mkdir(localfile_init)
t=paramiko.Transport(('10.15.1.27',22))
t.connect(username='oracle',password='oracle')
sftp=paramiko.SFTPClient.from_transport(t)
date=(time.strftime("%Y%m%d"))
yesterday=int((time.strftime("%Y%m%d")))-1
print(date,yesterday)
remotefile = r'/dbhome/oracle/db_tools/report/xyh/' + date + '.xyh.txt'
localfile = localfile_init + '\\' + date + '.xyh.txt'
try:
    sftp.get(remotefile,localfile)
except FileNotFoundError:
    print ('\033[32;1mFileNotFoundError\033[0m')
    remotefile = r'/dbhome/oracle/db_tools/report/xyh/' + str(yesterday) + '.xyh.txt'
    localfile = localfile_init + '\\' + str(yesterday) + '.xyh.txt'
    sftp.get(remotefile,localfile)
except Exception as e:
    print ('error:',e)
else:
    sftp.get(remotefile,localfile)
t.close()
# 将192.170.17.11的巡检报告传送到本地D:\GitHub\report
t=paramiko.Transport(('192.170.17.11',22))
t.connect(username='oracle',password='oracle')
sftp=paramiko.SFTPClient.from_transport(t)
date=(time.strftime("%Y%m%d"))
yesterday=int((time.strftime("%Y%m%d")))-1
print(date,yesterday)
remotefile = r'/dbhome/oracle/db_tools/reportall/oadb1.' + date + '.xyh.txt'
localfile1 = localfile_init + '\\oadb1.' + date + '.xyh.txt'
try:
    sftp.get(remotefile,localfile1)
except FileNotFoundError:
    print ('\033[32;1mFileNotFoundError\033[0m')
    remotefile = r'/dbhome/oracle/db_tools/reportall/oadb1.' + str(yesterday) + '.xyh.txt'
    localfile1 = localfile_init + '\\oadb1.' + str(yesterday) + '.xyh.txt'
    sftp.get(remotefile,localfile1)
except Exception as e:
    print ('error:',e)
else:
    sftp.get(remotefile,localfile1)
t.close()

# 将192.170.17.13的巡检报告传送到本地D:\GitHub\report
t=paramiko.Transport(('192.170.17.13',22))
t.connect(username='oracle',password='oracle')
sftp=paramiko.SFTPClient.from_transport(t)
date=(time.strftime("%Y%m%d"))
yesterday=int((time.strftime("%Y%m%d")))-1
print(date,yesterday)
remotefile = r'/dbhome/oracle/db_tools/report/dzda1.' + date + '.xyh.log'
localfile2 = localfile_init + '\\dzda1.' + date + '.xyh.txt'
try:
    sftp.get(remotefile,localfile2)
except FileNotFoundError:
    print ('\033[32;1mFileNotFoundError\033[0m')
    remotefile = r'/dbhome/oracle/db_tools/report/dzda1.' + str(yesterday) + '.xyh.log'
    localfile2 = localfile_init + '\\dzda1.' + str(yesterday) + '.xyh.txt'
    sftp.get(remotefile,localfile2)
except Exception as e:
    print ('error:',e)
else:
    sftp.get(remotefile,localfile2)
t.close()

#将localfile,localfile1及localfile2 写入1.txt
#f=open(localfile,'r',encoding='gb1830')
f=open(localfile,'r',encoding='gbk',errors='ignore')
#f=open(localfile)
content=f.read()
#print(content)
print(type(content))
content_utf8 = content.encode('utf-8')

f1=open(localfile1,'r',encoding='utf-8',errors='ignore')
#f=open(localfile)
content1=f1.read()
#print(content1)
print(type(content1))
content1_utf8 = content1.encode('utf-8')

f2=open(localfile2,'r',encoding='utf-8',errors='ignore')
#f=open(localfile)
content2=f2.read()
#print(content2)
print(type(content2))
content2_utf8 = content2.encode('utf-8')

#print(content_utf8)
f.close()
fo = open("1.txt", "wb")
fo.write(content_utf8)
fo.write(content1_utf8)
fo.write(content2_utf8)
fo.close()
print("输出filenotfoundError，则1.txt为昨日报告，否则为今日，按任意键退出")
msvcrt.getch()
